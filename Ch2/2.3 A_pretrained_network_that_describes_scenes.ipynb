# %% [markdown]
# # NeuralTalk2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 처음 절반은 장면에 대한 설명을 generative하고 나머지 절반은 rnn으로 문장을 만들어 낸다. 두 개의 네트워크는 image-caption pair로부터 학습된다.

# %%
# !git clone https://github.com/deep-learning-with-pytorch/ImageCaptioning.pytorch
# Out:
# Cloning into 'ImageCaptioning.pytorch'...
# remote: Enumerating objects: 515, done.
# remote: Total 515 (delta 0), reused 0 (delta 0), pack-reused 515
# Receiving objects: 100% (515/515), 206.53 MiB | 32.99 MiB/s, done.
# Resolving deltas: 100% (327/327), done.
# Checking out files: 100% (28/28), done.

# %%
# %mkdir data

# %%
# !wget https://raw.githubusercontent.com/deep-learning-with-pytorch/dlwpt-code/master/data/p1ch2/horse.jpg
# Out:
# --2021-03-19 07:33:08--  https://raw.githubusercontent.com/deep-learning-with-pytorch/dlwpt-code/master/data/p1ch2/horse.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 385347 (376K) [image/jpeg]
# Saving to: ‘horse.jpg’
#
# horse.jpg           100%[===================>] 376.32K  --.-KB/s    in 0.03s
#
# 2021-03-19 07:33:08 (14.1 MB/s) - ‘horse.jpg’ saved [385347/385347]

# %%
# !cp horse.jpg ./data

# %%
# %cd ImageCaptioning.pytorch/
# Out:
# /content/ImageCaptioning.pytorch

# %%
# !python eval.py --model ./data/FC/fc-model.pth --infos_path ./data/FC/fc-infos.pkl --image_folder ../data
# Out:
# DataLoaderRaw loading images from folder:  ../data
# 0
# listing all images in directory ../data
# DataLoaderRaw found  1  images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1709: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1698: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /content/ImageCaptioning.pytorch/models/FCModel.py:147: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   logprobs = F.log_softmax(self.logit(output))
# /content/ImageCaptioning.pytorch/models/FCModel.py:123: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# ...

# %% [markdown]
# <img src="https://raw.githubusercontent.com/deep-learning-with-pytorch/dlwpt-code/master/data/p1ch2/horse.jpg" width = "500">
#
#
# **a person riding a horse on a beach**
